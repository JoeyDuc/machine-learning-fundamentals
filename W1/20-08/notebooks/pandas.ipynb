# %%
import pandas as pd
data = {
    'Name': ['A', 'B', 'C', 'D'],
    'Gender': ['M', 'F', 'F', 'M']
}
data_frame = pd.DataFrame(data)

print(type(data_frame))
# Out:
# <class 'pandas.DataFrame'>

# %%
data_frame
# Out:
#   Name Gender
# 0    A      M
# 1    B      F
# 2    C      F
# 3    D      M

# %%
name_series = data_frame['Name']
print(type(name_series))
# Out:
# <class 'pandas.Series'>

# %%
name_series
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# Name: Name, dtype: str

# %%
gender_series = data_frame['Gender']
print(type(gender_series))
# Out:
# <class 'pandas.Series'>

# %%
gender_series
# Out:
# 0    M
# 1    F
# 2    F
# 3    M
# Name: Gender, dtype: str

# %%
new_df = pd.concat(
    [name_series, gender_series], axis = 1
)
print(type(new_df))
# Out:
# <class 'pandas.DataFrame'>

# %%
new_df
# Out:
#   Name Gender
# 0    A      M
# 1    B      F
# 2    C      F
# 3    D      M

# %%
import xarray as xr
data_1 = {
    'Name': ['A', 'B', 'C', 'D'],
    'Gender': ['M', 'F', 'F', 'M']
}
data_2 = {
    'Name': ['E', 'F', 'G', 'H', 'I'],
    'Gender': ['M', 'M', 'F', 'F', 'M']
}

df1 = pd.DataFrame(data_1).to_xarray()
df2 = pd.DataFrame(data_2).to_xarray()

panel_data = xr.concat(
    [df1, df2], dim = 'panel_dim'
)
panel_data
# Out:
# /var/folders/dj/wq5m3k51329gtd7_lpqdxj5m0000gn/T/ipykernel_83293/1022771945.py:14: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'index' ('index',) The recommendation is to set join explicitly for this case.
#   panel_data = xr.concat(
# <xarray.Dataset> Size: 200B
# Dimensions:  (panel_dim: 2, index: 5)
# Coordinates:
#   * index    (index) int64 40B 0 1 2 3 4
# Dimensions without coordinates: panel_dim
# Data variables:
#     Name     (panel_dim, index) object 80B 'A' 'B' 'C' 'D' ... 'F' 'G' 'H' 'I'
#     Gender   (panel_dim, index) object 80B 'M' 'F' 'F' 'M' ... 'M' 'F' 'F' 'M'

# %%
import numpy as np
DATASET_PATH = '../data/Pokemon.csv'
data = pd.read_csv(DATASET_PATH)

data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
data.to_csv('modified.csv')

data.to_excel('modified.xlsx', index = False)

data.to_csv('modified_tab.csv', sep = '\t')

# %%
data.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
data.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
data.tail(5)
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='str')

# %%
data[['Name', 'HP']]
# Out:
#                       Name  HP
# 0                Bulbasaur  45
# 1                  Ivysaur  60
# 2                 Venusaur  80
# 3    VenusaurMega Venusaur  80
# 4               Charmander  39
# ..                     ...  ..
# 795                Diancie  50
# 796    DiancieMega Diancie  50
# 797    HoopaHoopa Confined  80
# 798     HoopaHoopa Unbound  80
# 799              Volcanion  80
#
# [800 rows x 2 columns]

# %%
data[['Name', 'Total', 'Attack']][:10:2]
# Out:
#                         Name  Total  Attack
# 0                  Bulbasaur    318      49
# 2                   Venusaur    525      82
# 4                 Charmander    309      52
# 6                  Charizard    534      84
# 8  CharizardMega Charizard Y    634     104

# %%
data.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
data = data.drop(columns = ['Total'])
data.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
data['Total'] = data['Attack'] + data['Defense'] + data['HP']
data.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    143
# 1       80     60           1      False    185
# 2      100     80           1      False    245
# 3      120     80           1      False    303
# 4       50     65           1      False    134

# %%
cols = list(data.columns.values)
print(cols)
# Out:
# ['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Total']

# %%
data[cols[0:4] + [cols[-1]] + cols[4:-1]]
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    143  45      49       49
# 1      2                Ivysaur    Grass  Poison    185  60      62       63
# 2      3               Venusaur    Grass  Poison    245  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    303  80     100      123
# 4      4             Charmander     Fire     NaN    134  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    300  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    320  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    250  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    300  80     160       60
# 799  721              Volcanion     Fire   Water    310  80     110      120
#
# ...

# %%
data.iloc[[3, 6, 9]]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 6  6              Charizard   Fire  Flying  78      84       78      109
# 9  7               Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 3      120     80           1      False    303
# 6       85    100           1      False    240
# 9       64     43           1      False    157

# %%
data.iloc[3:9]
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 3      120     80           1      False    303
# 4       50     65           1      False    134
# 5       65     80           1      False    180
# 6       85    100           1      False    240
# 7       85    100           1      False    319
# 8      115    100           1      False    260

# %%
data.loc[data['Legendary'] == True].head(5)
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 156  144             Articuno       Ice    Flying   90      85      100
# 157  145               Zapdos  Electric    Flying   90      90       85
# 158  146              Moltres      Fire    Flying   90     100       90
# 162  150               Mewtwo   Psychic       NaN  106     110       90
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 156       95      125     85           1       True    275
# 157      125       90    100           1       True    265
# 158      125       85     90           1       True    280
# 162      154       90    130           1       True    306
# 163      154      100    130           1       True    396

# %%
data.loc[data['Attack'] >= 180].loc[data['Legendary'] == True]
# Out:
#        #                   Name   Type 1    Type 2   HP  Attack  Defense  \
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 424  383  GroudonPrimal Groudon   Ground      Fire  100     180      160
# 426  384  RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 429  386     DeoxysAttack Forme  Psychic       NaN   50     180       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 163      154      100    130           1       True    396
# 424      150       90     90           3       True    440
# 426      180      100    115           3       True    385
# 429      180       20    150           3       True    250

# %%
data.loc[data['Attack'] >= 49, ['Name', 'Type 2']]
# Out:
#                       Name  Type 2
# 0                Bulbasaur  Poison
# 1                  Ivysaur  Poison
# 2                 Venusaur  Poison
# 3    VenusaurMega Venusaur  Poison
# 4               Charmander     NaN
# ..                     ...     ...
# 795                Diancie   Fairy
# 796    DiancieMega Diancie   Fairy
# 797    HoopaHoopa Confined   Ghost
# 798     HoopaHoopa Unbound    Dark
# 799              Volcanion   Water
#
# [670 rows x 2 columns]

# %%
data.loc[(data['Type 1'] == 'Grass') & (data['Type 2'] == 'Poison')].head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary  Total
# 0           1      False    143
# 1           1      False    185
# 2           1      False    245

# %%
data.loc[(data['Type 1'] == 'Grass') | (data['Type 2'] == 'Poison')][0::10].loc[data['HP'] > 50].head(3)
# Out:
#        #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 50    45  Vileplume  Grass  Poison  75      80       85      110       90
# 101   94     Gengar  Ghost  Poison  60      65       60      130       75
# 197  182  Bellossom  Grass     NaN  75      80       95       90      100
#
#      Speed  Generation  Legendary  Total
# 50      50           1      False    240
# 101    110           1      False    185
# 197     50           2      False    250

# %%
data.loc[data['Name'].str.contains('Mega')].head(3)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 3      120     80           1      False    303
# 7       85    100           1      False    319
# 8      115    100           1      False    260

# %%
data.loc[data['Type 1'].str.contains('Fire|grass', regex=True, case = False)]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4      4             Charmander   Fire     NaN   39      52       43       60
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 735  667                 Litleo   Fire  Normal   62      50       58       73
# 736  668                 Pyroar   Fire  Normal   86      68       72      109
# 740  672                 Skiddo  Grass     NaN   66      65       48       62
# 741  673                 Gogoat  Grass     NaN  123     100       62       97
# 799  721              Volcanion   Fire   Water   80     110      120      130
#
# ...

# %%
import re

data.loc[data['Name'].str.contains('pi[a-z]*', flags=re.I, regex = True)]
# Out:
#        #                     Name    Type 1    Type 2   HP  Attack  Defense  \
# 13    10                 Caterpie       Bug       NaN   45      30       35
# 20    16                   Pidgey    Normal    Flying   40      45       40
# 21    17                Pidgeotto    Normal    Flying   63      60       55
# 22    18                  Pidgeot    Normal    Flying   83      80       75
# 23    18      PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25                  Pikachu  Electric       NaN   35      55       40
# 42    37                   Vulpix      Fire       NaN   38      41       40
# 76    70               Weepinbell     Grass    Poison   65      90       50
# 84    78                 Rapidash      Fire       NaN   65     100       70
# 136  127                   Pinsir       Bug       NaN   65     125      100
# 137  127        PinsirMega Pinsir       Bug    Flying   65     155      120
# ...

# %%
data.loc[data['Name'].str.contains('^pi[a-z]*', flags = re.I, regex = True)].head(3)

#flags = re.I : Ignorecase => dung de phan biet chu hoa, neu = True thi khong xet viet hoa hay thuong
# Out:
#      #       Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 20  16     Pidgey  Normal  Flying  40      45       40       35       35
# 21  17  Pidgeotto  Normal  Flying  63      60       55       50       50
# 22  18    Pidgeot  Normal  Flying  83      80       75       70       70
#
#     Speed  Generation  Legendary  Total
# 20     56           1      False    125
# 21     71           1      False    178
# 22    101           1      False    238

# %%
data.loc[data['Name'].str.contains('^pi.*', flags = re.I, regex = True)].head(3)
# Out:
#      #       Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 20  16     Pidgey  Normal  Flying  40      45       40       35       35
# 21  17  Pidgeotto  Normal  Flying  63      60       55       50       50
# 22  18    Pidgeot  Normal  Flying  83      80       75       70       70
#
#     Speed  Generation  Legendary  Total
# 20     56           1      False    125
# 21     71           1      False    178
# 22    101           1      False    238

# %%
data.loc[data['Name'].str.contains('^pi[abc]', flags = re.I, regex = True)]
# Out:
#        #   Name    Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 186  172  Pichu  Electric    NaN  20      40       15       35       35
#
#      Speed  Generation  Legendary  Total
# 186     60           2      False     75

# %%
data.sort_values('HP', ascending = False)
# Out:
#        #       Name   Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 261  242    Blissey   Normal    NaN  255      10       10       75      135
# 121  113    Chansey   Normal    NaN  250       5        5       35      105
# 217  202  Wobbuffet  Psychic    NaN  190      33       58       33       58
# 351  321    Wailord    Water    NaN  170      90       45       90       45
# 655  594  Alomomola    Water    NaN  165      75       80       40       45
# ..   ...        ...      ...    ...  ...     ...      ...      ...      ...
# 139  129   Magikarp    Water    NaN   20      10       55       15       20
# 381  349     Feebas    Water    NaN   20      15       20       10       55
# 388  355    Duskull    Ghost    NaN   20      40       90       30       90
# 55    50    Diglett   Ground    NaN   10      55       25       35       45
# 316  292   Shedinja      Bug  Ghost    1      90       45       30       30
#
#      Speed  Generation  Legendary  Total
# ...

# %%
data.sort_values(['HP', 'Attack', 'Type 2'], ascending = [True, False, True])
# Out:
#        #       Name    Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja       Bug  Ghost    1      90       45       30       30
# 55    50    Diglett    Ground    NaN   10      55       25       35       45
# 186  172      Pichu  Electric    NaN   20      40       15       35       35
# 388  355    Duskull     Ghost    NaN   20      40       90       30       90
# 487  439   Mime Jr.   Psychic  Fairy   20      25       45       70       90
# ..   ...        ...       ...    ...  ...     ...      ...      ...      ...
# 655  594  Alomomola     Water    NaN  165      75       80       40       45
# 351  321    Wailord     Water    NaN  170      90       45       90       45
# 217  202  Wobbuffet   Psychic    NaN  190      33       58       33       58
# 121  113    Chansey    Normal    NaN  250       5        5       35      105
# 261  242    Blissey    Normal    NaN  255      10       10       75      135
#
#      Speed  Generation  Legendary  Total
# ...

# %%
new_data = data.loc[(data['Type 1'] == 'Grass') | (data['Type 2'] == 'Poison')][0::10].loc[data['HP'] > 50].head(3)
new_data
# Out:
#        #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 50    45  Vileplume  Grass  Poison  75      80       85      110       90
# 101   94     Gengar  Ghost  Poison  60      65       60      130       75
# 197  182  Bellossom  Grass     NaN  75      80       95       90      100
#
#      Speed  Generation  Legendary  Total
# 50      50           1      False    240
# 101    110           1      False    185
# 197     50           2      False    250

# %%
new_data.reset_index(drop = True, inplace = True) #khong can gan lai
new_data
# Out:
#      #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0   45  Vileplume  Grass  Poison  75      80       85      110       90
# 1   94     Gengar  Ghost  Poison  60      65       60      130       75
# 2  182  Bellossom  Grass     NaN  75      80       95       90      100
#
#    Speed  Generation  Legendary  Total
# 0     50           1      False    240
# 1    110           1      False    185
# 2     50           2      False    250

# %%
data.groupby('Type 1')[['Defense']].mean().sort_values('Defense', ascending = False).head(10)
# Out:
#            Defense
# Type 1
# Steel   126.370370
# Rock    100.795455
# Dragon   86.375000
# Ground   84.843750
# Ghost    81.187500
# Water    72.946429
# Ice      71.416667
# Grass    70.800000
# Bug      70.724638
# Dark     70.225806

# %%
df = data.groupby(['Type 1']).agg({
    'Attack': 'mean',
    'Defense': 'sum',
    'Speed': lambda x : len(x) #Dem so dong
})
df.head(10)
# Out:
#               Attack  Defense  Speed
# Type 1
# Bug        70.971014     4880     69
# Dark       88.387097     2177     31
# Dragon    112.125000     2764     32
# Electric   69.090909     2917     44
# Fairy      61.529412     1117     17
# Fighting   96.777778     1780     27
# Fire       84.769231     3524     52
# Flying     78.750000      265      4
# Ghost      73.781250     2598     32
# Grass      73.214286     4956     70

# %%
df = data.groupby('Type 1')[['HP', 'Attack']].mean()
df
# Out:
#                  HP      Attack
# Type 1
# Bug       56.884058   70.971014
# Dark      66.806452   88.387097
# Dragon    83.312500  112.125000
# Electric  59.795455   69.090909
# Fairy     74.117647   61.529412
# Fighting  69.851852   96.777778
# Fire      69.903846   84.769231
# Flying    70.750000   78.750000
# Ghost     64.437500   73.781250
# Grass     67.271429   73.214286
# Ground    73.781250   95.750000
# Ice       72.000000   72.750000
# Normal    77.275510   73.469388
# Poison    67.250000   74.678571
# Psychic   70.631579   71.456140
# Rock      65.363636   92.863636
# Steel     65.222222   92.703704
# Water     72.062500   74.151786
